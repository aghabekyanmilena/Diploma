# %%
# %pip install -q rdkit dscribe
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

from rdkit import Chem
from ase import Atoms
from dscribe.descriptors import ACSF
# Out:
# 2026-05-10 13:23:08.288819: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-10 13:23:08.363128: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-10 13:23:08.689261: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-10 13:23:08.689332: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-10 13:23:08.758103: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-10 13:23:08.888675: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-10 13:23:08.894993: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-10 13:23:10.198769: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
df = pd.read_csv("../gdb9.csv")

# %%
df.head()
# Out:
#   mol_id          A           B           C      mu  alpha    homo    lumo  \
# 0  gdb_1  157.71180  157.709970  157.706990  0.0000  13.21 -0.3877  0.1171
# 1  gdb_2  293.60975  293.541110  191.393970  1.6256   9.46 -0.2570  0.0829
# 2  gdb_3  799.58812  437.903860  282.945450  1.8511   6.31 -0.2928  0.0687
# 3  gdb_4    0.00000   35.610036   35.610036  0.0000  16.28 -0.2845  0.0506
# 4  gdb_5    0.00000   44.593883   44.593883  2.8937  12.99 -0.3604  0.0191
#
#       gap       r2      zpve         u0       u298       h298       g298  \
# 0  0.5048  35.3641  0.044749 -40.478930 -40.476062 -40.475117 -40.498597
# 1  0.3399  26.1563  0.034358 -56.525887 -56.523026 -56.522082 -56.544961
# 2  0.3615  19.0002  0.021375 -76.404702 -76.401867 -76.400922 -76.422349
# 3  0.3351  59.5248  0.026841 -77.308427 -77.305527 -77.304583 -77.327429
# 4  0.3796  48.7476  0.016601 -93.411888 -93.409370 -93.408425 -93.431246
#
#       cv     u0_atom   u298_atom   h298_atom   g298_atom
# 0  6.469 -395.999595 -398.643290 -401.014647 -372.471772
# 1  6.316 -276.861363 -278.620271 -280.399259 -259.338802
# 2  6.002 -213.087624 -213.974294 -215.159658 -201.407171
# 3  8.574 -385.501997 -387.237686 -389.016047 -365.800724
# 4  6.278 -301.820534 -302.906752 -304.091489 -288.720028

# %%
target_column = "u0_atom"

# %%
df.shape
# Out:
# (133885, 20)

# %%
suppl = Chem.SDMolSupplier("../gdb9.sdf", removeHs=False)
print(len(suppl))
# Out:
# 133885

# %%
def extract_geometry(mol):
    conf = mol.GetConformer()

    atomic_numbers = []
    positions = []

    for atom in mol.GetAtoms():
        atomic_numbers.append(atom.GetAtomicNum())
        pos = conf.GetAtomPosition(atom.GetIdx())
        positions.append([pos.x, pos.y, pos.z])

    return np.array(atomic_numbers), np.array(positions)

# %%
Z, R = extract_geometry(suppl[0])
print(Z.shape, R.shape)
# Out:
# (5,) (5, 3)

# %%
def rdkit_to_ase(mol):
    Z, R = extract_geometry(mol)
    symbols = [Chem.PeriodicTable.GetElementSymbol(
        Chem.GetPeriodicTable(), int(z)) for z in Z]

    return Atoms(symbols=symbols, positions=R)

# %%
species = ["H", "C", "N", "O", "F"]

acsf = ACSF(
    species=species,
    r_cut=5.0,
    g2_params=[
        [0.5, 0.0], [1.0, 0.0], [2.0, 0.0],
        [1.0, 1.0], [1.0, 2.0], [2.0, 1.0],
    ],
    g4_params=[[1.0, 1.0, 1.0], [1.0, 2.0, 1.0], [2.0, 1.0, 1.0]],
)

# %%
atoms = rdkit_to_ase(suppl[0])
features = acsf.create(atoms)
print(features.shape)
# Out:
# (5, 80)

# %%
max_atoms = 0

for mol in suppl:
    if mol is None:
        continue
    max_atoms = max(max_atoms, mol.GetNumAtoms())

print("Max atoms:", max_atoms)
# Out:
# Max atoms: 29

# %%
X_data = []
mask_data = []
y_data = []

for i, mol in enumerate(suppl):
    if mol is None:
        continue

    atoms = rdkit_to_ase(mol)
    features = acsf.create(atoms)
    n = features.shape[0]

    padded = np.zeros((max_atoms, features.shape[1]))
    padded[:n, :] = features

    # 1 for real atoms, 0 for padding — required so padded slots are not summed
    # (dense layers output non-zero bias even for all-zero ACSF rows).
    m = np.zeros(max_atoms, dtype=np.float32)
    m[:n] = 1.0

    X_data.append(padded)
    mask_data.append(m)
    y_data.append(df.iloc[i][target_column])

X_data = np.asarray(X_data, dtype=np.float32)
atom_mask = np.asarray(mask_data, dtype=np.float32)
y_data = np.asarray(y_data, dtype=np.float32)

print(X_data.shape)
print(atom_mask.shape)
print(y_data.shape)
# Out:
# (131929, 29, 80)
# (131929, 29)
# (131929,)

# %%
def atomic_network(n_features):
    reg = tf.keras.regularizers.l2(1e-6)
    inputs = tf.keras.layers.Input(shape=(n_features,))
    x = tf.keras.layers.Dense(160, activation="relu", kernel_regularizer=reg)(inputs)
    x = tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=reg)(x)
    x = tf.keras.layers.Dense(96, activation="relu", kernel_regularizer=reg)(x)
    outputs = tf.keras.layers.Dense(1)(x)
    return tf.keras.Model(inputs, outputs)

# %%
n_features = X_data.shape[2]

atomic_model = atomic_network(n_features)

feat_in = tf.keras.layers.Input(shape=(max_atoms, n_features), name="features")
mask_in = tf.keras.layers.Input(shape=(max_atoms,), name="mask")

atomic_energies = tf.keras.layers.TimeDistributed(atomic_model)(feat_in)

def masked_atomic_sum(args):
    ae, mask = args
    return tf.reduce_sum(ae * tf.expand_dims(mask, -1), axis=1)

total_energy = tf.keras.layers.Lambda(masked_atomic_sum)([atomic_energies, mask_in])

model = tf.keras.Model(inputs=[feat_in, mask_in], outputs=total_energy)

model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  features (InputLayer)       [(None, 29, 80)]             0         []
#
#  time_distributed (TimeDist  (None, 29, 1)                46049     ['features[0][0]']
#  ributed)
#
#  mask (InputLayer)           [(None, 29)]                 0         []
#
#  lambda (Lambda)             (None, 1)                    0         ['time_distributed[0][0]',
#                                                                      'mask[0][0]']
#
# ==================================================================================================
# Total params: 46049 (179.88 KB)
# Trainable params: 46049 (179.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# 2026-05-10 13:25:14.000958: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="mse",
    metrics=["mae"],
)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, m_train, m_test, y_train, y_test = train_test_split(
    X_data, atom_mask, y_data, test_size=0.2, random_state=42
)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=10, restore_best_weights=True, min_delta=1e-4
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=4, min_lr=1e-5
    ),
]

model.fit(
    [X_train, m_train],
    y_train,
    validation_split=0.2,
    epochs=80,
    batch_size=64,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/80
# 1320/1320 [==============================] - 8s 6ms/step - loss: 67311.1406 - mae: 88.0197 - val_loss: 991.1286 - val_mae: 25.0446 - lr: 0.0010
# Epoch 2/80
# 1320/1320 [==============================] - 7s 5ms/step - loss:
80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 38.9001 - mae: 4.5950 - val_loss: 40.4866 - val_mae: 4.5741 - lr: 2.5000e-04
# Epoch 50/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 39.7624 - mae: 4.6691 - val_loss: 64.1771 - val_mae: 6.1436 - lr: 2.5000e-04
# Epoch 51/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 39.3809 - mae: 4.6333 - val_loss: 47.6740 - val_mae: 5.1077 - lr: 2.5000e-04
# Epoch 52/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 38.6024 - mae: 4.5844 - val_loss: 42.5843 - val_mae: 4.7182 - lr: 2.5000e-04
# Epoch 53/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 35.2850 - mae: 4.3290 - val_loss: 36.5074 - val_mae: 4.4476 - lr: 1.2500e-04
# Epoch 54/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 35.2529 - mae: 4.3325 - val_loss: 39.1425 - val_mae: 4.4223 - lr: 1.2500e-04
# Epoch 55/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 34.9642 - mae: 4.3179 - val_loss: 36.2282 - val_mae: 4.4307 - lr: 1.2500e-04
# Epoch 56/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 35.3284 - mae: 4.3516 - val_loss: 34.0986 - val_mae: 4.1983 - lr: 1.2500e-04
# Epoch 57/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 34.5207 - mae: 4.2866 - val_loss: 36.5531 - val_mae: 4.2657 - lr: 1.2500e-04
# Epoch 58/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 34.5559 - mae: 4.2810 - val_loss: 34.9352 - val_mae: 4.3419 - lr: 1.2500e-04
# Epoch 59/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 34.6163 - mae: 4.2919 - val_loss: 33.3993 - val_mae: 4.1316 - lr: 1.2500e-04
# Epoch 60/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 34.4501 - mae: 4.2878 - val_loss: 35.5669 - val_mae: 4.3977 - lr: 1.2500e-04
# Epoch 61/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 33.7052 - mae: 4.2181 - val_loss: 36.0694 - val_mae: 4.4727 - lr: 1.2500e-04
# Epoch 62/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 34.2243 - mae: 4.2736 - val_loss: 34.4782 - val_mae: 4.1833 - lr: 1.2500e-04
# Epoch 63/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 33.2373 - mae: 4.1845 - val_loss: 32.6164 - val_mae: 4.0629 - lr: 1.2500e-04
# Epoch 64/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 33.6495 - mae: 4.2209 - val_loss: 34.6453 - val_mae: 4.2037 - lr: 1.2500e-04
# Epoch 65/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 33.3107 - mae: 4.2003 - val_loss: 47.0922 - val_mae: 5.1439 - lr: 1.2500e-04
# Epoch 66/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 33.1718 - mae: 4.1913 - val_loss: 40.6506 - val_mae: 4.5455 - lr: 1.2500e-04
# Epoch 67/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 33.2091 - mae: 4.1929 - val_loss: 33.1122 - val_mae: 4.0437 - lr: 1.2500e-04
# Epoch 68/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 31.1887 - mae: 4.0251 - val_loss: 32.1534 - val_mae: 4.0380 - lr: 6.2500e-05
# Epoch 69/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 31.4694 - mae: 4.0510 - val_loss: 32.8329 - val_mae: 4.0348 - lr: 6.2500e-05
# Epoch 70/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 31.4760 - mae: 4.0476 - val_loss: 32.0332 - val_mae: 3.9862 - lr: 6.2500e-05
# Epoch 71/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 30.8837 - mae: 4.0017 - val_loss: 31.4472 - val_mae: 3.9920 - lr: 6.2500e-05
# Epoch 72/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 31.3925 - mae: 4.0515 - val_loss: 36.2355 - val_mae: 4.2602 - lr: 6.2500e-05
# Epoch 73/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 30.8299 - mae: 4.0035 - val_loss: 32.4402 - val_mae: 4.0993 - lr: 6.2500e-05
# Epoch 74/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 31.2486 - mae: 4.0364 - val_loss: 32.3398 - val_mae: 4.1348 - lr: 6.2500e-05
# Epoch 75/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 30.8261 - mae: 4.0030 - val_loss: 34.3597 - val_mae: 4.1447 - lr: 6.2500e-05
# Epoch 76/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 29.8689 - mae: 3.9157 - val_loss: 31.0611 - val_mae: 3.9306 - lr: 3.1250e-05
# Epoch 77/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 29.9369 - mae: 3.9242 - val_loss: 32.2026 - val_mae: 4.1176 - lr: 3.1250e-05
# Epoch 78/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 29.8562 - mae: 3.9183 - val_loss: 30.9182 - val_mae: 3.9324 - lr: 3.1250e-05
# Epoch 79/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 29.8566 - mae: 3.9224 - val_loss: 30.9408 - val_mae: 3.9198 - lr: 3.1250e-05
# Epoch 80/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 29.7952 - mae: 3.9196 - val_loss: 33.3125 - val_mae: 4.2431 - lr: 3.1250e-05

# %%
model.evaluate([X_test, m_test], y_test, verbose=1)
# Out:
# 825/825 [==============================] - 1s 1ms/step - loss: 32.3295 - mae: 4.2283
# [32.329532623291016, 4.228250503540039]

# %%
y_pred = model.predict([X_test, m_test], verbose=1)
# Out:
# 825/825 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_p = np.asarray(y_pred).reshape(-1)
print(f"Test MAE:  {mean_absolute_error(y_test, y_p):.6f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test, y_p)):.6f}")
print(f"Test R²:   {r2_score(y_test, y_p):.6f}")
# Out:
# Test MAE:  4.228249
# Test RMSE: 5.684090
# Test R²:   0.999441

# %%
print(
    "Test MAE (numpy):",
    float(np.mean(np.abs(y_test - np.asarray(y_pred).reshape(-1)))),
)
# Out:
# Test MAE (numpy): 4.228248596191406

# %%
import matplotlib.pyplot as plt

y_t = np.asarray(y_test).ravel()
y_p = np.asarray(y_pred).ravel()
lim = [min(y_t.min(), y_p.min()), max(y_t.max(), y_p.max())]

fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))

ax = axes[0]
ax.scatter(y_t, y_p, alpha=0.15, s=8, c="C0", rasterized=True)
ax.plot(lim, lim, "k--", lw=1, label="ideal")
ax.set_xlim(lim)
ax.set_ylim(lim)
ax.set_aspect("equal", adjustable="box")
ax.set_xlabel("True u0_atom")
ax.set_ylabel("Predicted u0_atom")
ax.set_title("Parity plot")
ax.legend(loc="upper left", frameon=False)

ax2 = axes[1]
res = y_p - y_t
ax2.scatter(y_t, res, alpha=0.15, s=8, c="C3", rasterized=True)
ax2.axhline(0.0, color="k", linestyle="--", lw=1)
ax2.set_xlabel("True u0_atom")
ax2.set_ylabel("Residual (pred − true)")
ax2.set_title("Residuals")

plt.tight_layout()
plt.show()

# %%
idx = 10
X_single = X_data[idx : idx + 1]
mask_single = atom_mask[idx : idx + 1]
prediction = model.predict([X_single, mask_single], verbose=0)
print("Predicted u0_atom:", float(prediction[0, 0]))
print("True u0_atom:     ", float(y_data[idx]))
# Out:
# Predicted u0_atom: -651.9229736328125
# True u0_atom:      -645.328369140625

# %%
print(np.asarray(y_pred).shape)
# Out:
# (26386, 1)
