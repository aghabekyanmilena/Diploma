# %%
# %pip install -q rdkit dscribe
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from rdkit import Chem
from ase import Atoms
from dscribe.descriptors import ACSF
# Out:
# 2026-05-10 13:46:37.668717: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-10 13:46:37.670783: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-10 13:46:37.697585: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-10 13:46:37.697609: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-10 13:46:37.698321: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-10 13:46:37.703290: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-10 13:46:37.703750: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-10 13:46:38.617392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.model_selection import train_test_split

# %%
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
df = pd.read_csv('../gdb9.csv')

# %%
df.head()
# Out:
#   mol_id          A           B           C      mu  alpha    homo    lumo  \
# 0  gdb_1  157.71180  157.709970  157.706990  0.0000  13.21 -0.3877  0.1171
# 1  gdb_2  293.60975  293.541110  191.393970  1.6256   9.46 -0.2570  0.0829
# 2  gdb_3  799.58812  437.903860  282.945450  1.8511   6.31 -0.2928  0.0687
# 3  gdb_4    0.00000   35.610036   35.610036  0.0000  16.28 -0.2845  0.0506
# 4  gdb_5    0.00000   44.593883   44.593883  2.8937  12.99 -0.3604  0.0191
#
#       gap       r2      zpve         u0       u298       h298       g298  \
# 0  0.5048  35.3641  0.044749 -40.478930 -40.476062 -40.475117 -40.498597
# 1  0.3399  26.1563  0.034358 -56.525887 -56.523026 -56.522082 -56.544961
# 2  0.3615  19.0002  0.021375 -76.404702 -76.401867 -76.400922 -76.422349
# 3  0.3351  59.5248  0.026841 -77.308427 -77.305527 -77.304583 -77.327429
# 4  0.3796  48.7476  0.016601 -93.411888 -93.409370 -93.408425 -93.431246
#
#       cv     u0_atom   u298_atom   h298_atom   g298_atom
# 0  6.469 -395.999595 -398.643290 -401.014647 -372.471772
# 1  6.316 -276.861363 -278.620271 -280.399259 -259.338802
# 2  6.002 -213.087624 -213.974294 -215.159658 -201.407171
# 3  8.574 -385.501997 -387.237686 -389.016047 -365.800724
# 4  6.278 -301.820534 -302.906752 -304.091489 -288.720028

# %%
df.shape
# Out:
# (133885, 20)

# %%
target_column = "gap"

# %%
suppl = Chem.SDMolSupplier("../gdb9.sdf", removeHs=False)
print(len(suppl))
# Out:
# 133885

# %%
def extract_geometry(mol):
  conf = mol.GetConformer()

  atomic_numbers = []
  positions = []

  for atom in mol.GetAtoms():
    atomic_numbers.append(atom.GetAtomicNum())
    pos = conf.GetAtomPosition(atom.GetIdx())
    positions.append([pos.x, pos.y, pos.z])

  return np.array(atomic_numbers), np.array(positions)

# %%
Z, R = extract_geometry(suppl[0])
print(Z.shape, R.shape)
# Out:
# (5,) (5, 3)

# %%
def rdkit_to_ase(mol):
  Z, R = extract_geometry(mol)
  symbols = [Chem.PeriodicTable.GetElementSymbol(
      Chem.GetPeriodicTable(), int(z)) for z in Z]

  return Atoms(symbols=symbols, positions=R)

# %%
species = ["H", "C", "N", "O", "F"]

acsf = ACSF(
    species=species,
    r_cut=5.0,
    g2_params=[
        [0.5, 0.0], [1.0, 0.0], [2.0, 0.0],
        [1.0, 1.0], [1.0, 2.0], [2.0, 1.0],
    ],
    g4_params=[[1.0, 1.0, 1.0], [1.0, 2.0, 1.0], [2.0, 1.0, 1.0]],
)

# %%
atoms = rdkit_to_ase(suppl[0])
features = acsf.create(atoms)
print(features.shape)
# Out:
# (5, 80)

# %%
max_atoms = 0

for mol in suppl:
  if mol is None:
    continue
  max_atoms = max(max_atoms, mol.GetNumAtoms())
print("Max atoms: ", max_atoms)
# Out:
# Max atoms:  29

# %%
X_data = []
mask_data = []
y_data = []

for i, mol in enumerate(suppl):
  if mol is None:
    continue

  atoms = rdkit_to_ase(mol)
  features = acsf.create(atoms)
  n = features.shape[0]

  padded = np.zeros((max_atoms, features.shape[1]))
  padded[:n, :] = features

  m = np.zeros(max_atoms, dtype=np.float32)
  m[:n] = 1.0

  X_data.append(padded)
  mask_data.append(m)
  y_data.append(df.iloc[i][target_column])

X_data = np.asarray(X_data, dtype=np.float32)
atom_mask = np.asarray(mask_data, dtype=np.float32)
y_data = np.asarray(y_data, dtype=np.float32)

print(X_data.shape, atom_mask.shape, y_data.shape)
# Out:
# (131929, 29, 80) (131929, 29) (131929,)

# %%
def atomic_network(n_features):
  reg = tf.keras.regularizers.l2(1e-6)
  inputs = tf.keras.layers.Input(shape=(n_features,))
  x = tf.keras.layers.Dense(160, activation="relu", kernel_regularizer=reg)(inputs)
  x = tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=reg)(x)
  x = tf.keras.layers.Dense(96, activation="relu", kernel_regularizer=reg)(x)
  outputs = tf.keras.layers.Dense(1)(x)
  return tf.keras.Model(inputs, outputs)

# %%
n_features = X_data.shape[2]
atomic_model = atomic_network(n_features)
feat_in = tf.keras.layers.Input(shape=(max_atoms, n_features), name="features")
mask_in = tf.keras.layers.Input(shape=(max_atoms,), name="mask")
atomic_energies = tf.keras.layers.TimeDistributed(atomic_model)(feat_in)

def masked_atomic_sum(args):
  ae, mask = args
  return tf.reduce_sum(ae * tf.expand_dims(mask, -1), axis=1)

total_energy = tf.keras.layers.Lambda(masked_atomic_sum)([atomic_energies, mask_in])
model = tf.keras.Model(inputs=[feat_in, mask_in], outputs=total_energy)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  features (InputLayer)       [(None, 29, 80)]             0         []
#
#  time_distributed (TimeDist  (None, 29, 1)                46049     ['features[0][0]']
#  ributed)
#
#  mask (InputLayer)           [(None, 29)]                 0         []
#
#  lambda (Lambda)             (None, 1)                    0         ['time_distributed[0][0]',
#                                                                      'mask[0][0]']
#
# ==================================================================================================
# Total params: 46049 (179.88 KB)
# Trainable params: 46049 (179.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# 2026-05-10 13:48:09.259543: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="mse",
    metrics=["mae"],
)

# %%
X_train, X_test, m_train, m_test, y_train, y_test = train_test_split(
    X_data, atom_mask, y_data, test_size=0.2, random_state=42
)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=10, restore_best_weights=True, min_delta=1e-4
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=4, min_lr=1e-5
    ),
]
model.fit(
    [X_train, m_train],
    y_train,
    validation_split=0.2,
    epochs=80,
    batch_size=64,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/80
# 1320/1320 [==============================] - 5s 3ms/step - loss: 0.1095 - mae: 0.0839 - val_loss: 0.0019 - val_mae: 0.0316 - lr: 0.0010
# Epoch 2/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.0020 - mae: 0.0324 - val_loss: 0.0033 - val_mae: 0.0466 - lr: 0.0010
# Epoch 3/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.0029 - mae: 0.0395 - val_loss: 0.0013 - val_mae: 0.0245 - lr: 0.0010
# Epoch 4/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.0024 - mae: 0.0367 - val_loss: 0.0010 - val_mae: 0.0212 - lr: 0.0010
# Epoch 5/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.0018 - mae: 0.0301 - val_loss: 0.0015 - val_mae: 0.0283 - lr: 0.0010
# Epoch 6/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.0013 - mae: 0.0258 - val_loss: 0.0010 - val_mae: 0.0226 - lr: 0.0010
# Epoch 7/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.0011 - mae: 0.0229 - val_loss: 7.8364e-04 - val_mae: 0.0180 - lr: 0.0010
# Epoch 8/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 9.1808e-04 - mae: 0.0206 - val_loss: 7.4904e-04 - val_mae: 0.0177 - lr: 0.0010
# Epoch 9/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 8.6481e-04 - mae: 0.0199 - val_loss: 0.0014 - val_mae: 0.0293 - lr: 0.0010
# Epoch 10/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 8.1199e-04 - mae: 0.0192 - val_loss: 0.0011 - val_mae: 0.0244 - lr: 0.0010
# Epoch 11/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 7.5448e-04 - mae: 0.0184 - val_loss: 8.1343e-04 - val_mae: 0.0202 - lr: 0.0010
# Epoch 12/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 6.2358e-04 - mae: 0.0163 - val_loss: 6.1705e-04 - val_mae: 0.0161 - lr: 5.0000e-04
# Epoch 13/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 6.1588e-04 - mae: 0.0163 - val_loss: 5.6789e-04 - val_mae: 0.0154 - lr: 5.0000e-04
# Epoch 14/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 5.8954e-04 - mae: 0.0161 - val_loss: 6.3255e-04 - val_mae: 0.0173 - lr: 5.0000e-04
# Epoch 15/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 5.7846e-04 - mae: 0.0161 - val_loss: 5.9153e-04 - val_mae: 0.0161 - lr: 5.0000e-04
# Epoch 16/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 5.4282e-04 - mae: 0.0155 - val_loss: 7.6131e-04 - val_mae: 0.0203 - lr: 5.0000e-04
# Epoch 17/80
# 1320/1320 [==============================] - 5s 3ms/step - loss: 4.5883e-04 - mae: 0.0139 - val_loss: 4.7292e-04 - val_mae: 0.0143 - lr: 2.5000e-04
# Epoch 18/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 4.4969e-04 - mae: 0.0139 - val_loss: 4.2649e-04 - val_mae: 0.0134 - lr: 2.5000e-04
# Epoch 19/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 4.3858e-04 - mae: 0.0138 - val_loss: 4.1546e-04 - val_mae: 0.0131 - lr: 2.5000e-04
# Epoch 20/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 4.2429e-04 - mae: 0.0136 - val_loss: 5.9079e-04 - val_mae: 0.0176 - lr: 2.5000e-04
# Epoch 21/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 4.1807e-04 - mae: 0.0136 - val_loss: 4.6475e-04 - val_mae: 0.0146 - lr: 2.5000e-04
# Epoch 22/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.7610e-04 - mae: 0.0126 - val_loss: 4.1016e-04 - val_mae: 0.0137 - lr: 1.2500e-04
# Epoch 23/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.7439e-04 - mae: 0.0126 - val_loss: 3.7312e-04 - val_mae: 0.0125 - lr: 1.2500e-04
# Epoch 24/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.6404e-04 - mae: 0.0124 - val_loss: 4.0289e-04 - val_mae: 0.0133 - lr: 1.2500e-04
# Epoch 25/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.6349e-04 - mae: 0.0124 - val_loss: 3.6636e-04 - val_mae: 0.0125 - lr: 1.2500e-04
# Epoch 26/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.6062e-04 - mae: 0.0124 - val_loss: 3.7833e-04 - val_mae: 0.0128 - lr: 1.2500e-04
# Epoch 27/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.5625e-04 - mae: 0.0123 - val_loss: 3.6718e-04 - val_mae: 0.0126 - lr: 1.2500e-04
# Epoch 28/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.5148e-04 - mae: 0.0122 - val_loss: 3.7676e-04 - val_mae: 0.0127 - lr: 1.2500e-04
# Epoch 29/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.5184e-04 - mae: 0.0123 - val_loss: 3.5790e-04 - val_mae: 0.0122 - lr: 1.2500e-04
# Epoch 30/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.3066e-04 - mae: 0.0117 - val_loss: 3.4978e-04 - val_mae: 0.0122 - lr: 6.2500e-05
# Epoch 31/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.2840e-04 - mae: 0.0117 - val_loss: 3.8737e-04 - val_mae: 0.0131 - lr: 6.2500e-05
# Epoch 32/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.2713e-04 - mae: 0.0117 - val_loss: 3.4063e-04 - val_mae: 0.0119 - lr: 6.2500e-05
# Epoch 33/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.2575e-04 - mae: 0.0117 - val_loss: 3.3603e-04 - val_mae: 0.0118 - lr: 6.2500e-05
# Epoch 34/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.1397e-04 - mae: 0.0113 - val_loss: 3.3030e-04 - val_mae: 0.0116 - lr: 3.1250e-05
# Epoch 35/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.1347e-04 - mae: 0.0113 - val_loss: 3.3907e-04 - val_mae: 0.0119 - lr: 3.1250e-05
# Epoch 36/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.1240e-04 - mae: 0.0113 - val_loss: 3.3125e-04 - val_mae: 0.0117 - lr: 3.1250e-05
# Epoch 37/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.1106e-04 - mae: 0.0113 - val_loss: 3.2888e-04 - val_mae: 0.0116 - lr: 3.1250e-05
# Epoch 38/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0597e-04 - mae: 0.0112 - val_loss: 3.2570e-04 - val_mae: 0.0115 - lr: 1.5625e-05
# Epoch 39/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0567e-04 - mae: 0.0112 - val_loss: 3.2472e-04 - val_mae: 0.0115 - lr: 1.5625e-05
# Epoch 40/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0514e-04 - mae: 0.0111 - val_loss: 3.2505e-04 - val_mae: 0.0115 - lr: 1.5625e-05
# Epoch 41/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0447e-04 - mae: 0.0111 - val_loss: 3.2835e-04 - val_mae: 0.0117 - lr: 1.5625e-05
# Epoch 42/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0194e-04 - mae: 0.0111 - val_loss: 3.2369e-04 - val_mae: 0.0115 - lr: 1.0000e-05
# Epoch 43/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0199e-04 - mae: 0.0111 - val_loss: 3.2362e-04 - val_mae: 0.0114 - lr: 1.0000e-05
# Epoch 44/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0119e-04 - mae: 0.0110 - val_loss: 3.2532e-04 - val_mae: 0.0116 - lr: 1.0000e-05
# Epoch 45/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0097e-04 - mae: 0.0110 - val_loss: 3.2366e-04 - val_mae: 0.0115 - lr: 1.0000e-05
# Epoch 46/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0092e-04 - mae: 0.0110 - val_loss: 3.2341e-04 - val_mae: 0.0115 - lr: 1.0000e-05
# Epoch 47/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0051e-04 - mae: 0.0110 - val_loss: 3.2526e-04 - val_mae: 0.0115 - lr: 1.0000e-05
# Epoch 48/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 3.0025e-04 - mae: 0.0110 - val_loss: 3.2208e-04 - val_mae: 0.0114 - lr: 1.0000e-05

# %%
model.evaluate([X_test, m_test], y_test, verbose=1)
# Out:
# 825/825 [==============================] - 1s 1ms/step - loss: 3.2222e-04 - mae: 0.0115
# [0.0003222238156013191, 0.011453727260231972]

# %%
y_pred = model.predict([X_test, m_test], verbose=1)
# Out:
# 825/825 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_p = np.asarray(y_pred).reshape(-1)
print(f"Test MAE:  {mean_absolute_error(y_test, y_p):.6f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test, y_p)):.6f}")
print(f"Test R²:   {r2_score(y_test, y_p):.6f}")
# Out:
# Test MAE:  0.011454
# Test RMSE: 0.015366
# Test R²:   0.896086

# %%
print(
    "Test MAE (numpy):",
    float(np.mean(np.abs(y_test - np.asarray(y_pred).reshape(-1)))),
)
# Out:
# Test MAE (numpy): 0.01145373284816742

# %%
import matplotlib.pyplot as plt

y_t = np.asarray(y_test).ravel()
y_p = np.asarray(y_pred).ravel()
lim = [min(y_t.min(), y_p.min()), max(y_t.max(), y_p.max())]

fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))
ax = axes[0]
ax.scatter(y_t, y_p, alpha=0.15, s=8, c="C0", rasterized=True)
ax.plot(lim, lim, "k--", lw=1, label="ideal")
ax.set_xlabel("True (target)")
ax.set_ylabel("Predicted")
ax.set_title("Parity")
ax.legend()
ax.set_aspect("equal", adjustable="box")

ax2 = axes[1]
res = y_p - y_t
ax2.scatter(y_t, res, alpha=0.15, s=8, c="C3", rasterized=True)
ax2.axhline(0.0, color="k", linestyle="--", lw=1)
ax2.set_xlabel("True (target)")
ax2.set_ylabel("Residual (pred − true)")
ax2.set_title("Residuals")

plt.tight_layout()
plt.show()

# %%
idx = 10
X_single = X_data[idx : idx + 1]
mask_single = atom_mask[idx : idx + 1]
prediction = model.predict([X_single, mask_single], verbose=0)
print("Predicted: ", prediction[0][0])
print("True: ", y_data[idx])
# Out:
# Predicted:  0.25594476
# True:  0.2342
