# %%
# %pip install -q rdkit dscribe
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import matplotlib.pyplot as plt

from rdkit import Chem
from ase import Atoms
from dscribe.descriptors import ACSF
# Out:
# 2026-05-10 13:54:14.530498: I tensorflow/core/util/port.cc:113] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-10 13:54:14.534689: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-10 13:54:14.579068: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2026-05-10 13:54:14.579094: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2026-05-10 13:54:14.587549: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2026-05-10 13:54:14.600516: I external/local_tsl/tsl/cuda/cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# 2026-05-10 13:54:14.601068: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2026-05-10 13:54:15.557558: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
from sklearn.model_selection import train_test_split

# %%
from rdkit import RDLogger
RDLogger.DisableLog('rdApp.*')

# %%
df = pd.read_csv('../gdb9.csv')

# %%
df.head()
# Out:
#   mol_id          A           B           C      mu  alpha    homo    lumo  \
# 0  gdb_1  157.71180  157.709970  157.706990  0.0000  13.21 -0.3877  0.1171
# 1  gdb_2  293.60975  293.541110  191.393970  1.6256   9.46 -0.2570  0.0829
# 2  gdb_3  799.58812  437.903860  282.945450  1.8511   6.31 -0.2928  0.0687
# 3  gdb_4    0.00000   35.610036   35.610036  0.0000  16.28 -0.2845  0.0506
# 4  gdb_5    0.00000   44.593883   44.593883  2.8937  12.99 -0.3604  0.0191
#
#       gap       r2      zpve         u0       u298       h298       g298  \
# 0  0.5048  35.3641  0.044749 -40.478930 -40.476062 -40.475117 -40.498597
# 1  0.3399  26.1563  0.034358 -56.525887 -56.523026 -56.522082 -56.544961
# 2  0.3615  19.0002  0.021375 -76.404702 -76.401867 -76.400922 -76.422349
# 3  0.3351  59.5248  0.026841 -77.308427 -77.305527 -77.304583 -77.327429
# 4  0.3796  48.7476  0.016601 -93.411888 -93.409370 -93.408425 -93.431246
#
#       cv     u0_atom   u298_atom   h298_atom   g298_atom
# 0  6.469 -395.999595 -398.643290 -401.014647 -372.471772
# 1  6.316 -276.861363 -278.620271 -280.399259 -259.338802
# 2  6.002 -213.087624 -213.974294 -215.159658 -201.407171
# 3  8.574 -385.501997 -387.237686 -389.016047 -365.800724
# 4  6.278 -301.820534 -302.906752 -304.091489 -288.720028

# %%
df.shape
# Out:
# (133885, 20)

# %%
target_column = "h298"

# %%
suppl = Chem.SDMolSupplier("../gdb9.sdf", removeHs=False)
print(len(suppl))
# Out:
# 133885

# %%
def extract_geometry(mol):
  conf = mol.GetConformer()

  atomic_numbers = []
  positions = []

  for atom in mol.GetAtoms():
    atomic_numbers.append(atom.GetAtomicNum())
    pos = conf.GetAtomPosition(atom.GetIdx())
    positions.append([pos.x, pos.y, pos.z])

  return np.array(atomic_numbers), np.array(positions)

# %%
Z, R = extract_geometry(suppl[0])
print(Z.shape, R.shape)
# Out:
# (5,) (5, 3)

# %%
def rdkit_to_ase(mol):
  Z, R = extract_geometry(mol)
  symbols = [Chem.PeriodicTable.GetElementSymbol(
      Chem.GetPeriodicTable(), int(z)) for z in Z]

  return Atoms(symbols=symbols, positions=R)

# %%
species = ["H", "C", "N", "O", "F"]

acsf = ACSF(
    species=species,
    r_cut=5.0,
    g2_params=[
        [0.5, 0.0], [1.0, 0.0], [2.0, 0.0],
        [1.0, 1.0], [1.0, 2.0], [2.0, 1.0],
    ],
    g4_params=[[1.0, 1.0, 1.0], [1.0, 2.0, 1.0], [2.0, 1.0, 1.0]],
)

# %%
atoms = rdkit_to_ase(suppl[0])
features = acsf.create(atoms)
print(features.shape)
# Out:
# (5, 80)

# %%
max_atoms = 0

for mol in suppl:
  if mol is None:
    continue
  max_atoms = max(max_atoms, mol.GetNumAtoms())
print("Max atoms: ", max_atoms)
# Out:
# Max atoms:  29

# %%
X_data = []
mask_data = []
y_data = []

for i, mol in enumerate(suppl):
  if mol is None:
    continue

  atoms = rdkit_to_ase(mol)
  features = acsf.create(atoms)
  n = features.shape[0]

  padded = np.zeros((max_atoms, features.shape[1]))
  padded[:n, :] = features

  m = np.zeros(max_atoms, dtype=np.float32)
  m[:n] = 1.0

  X_data.append(padded)
  mask_data.append(m)
  y_data.append(df.iloc[i][target_column])

X_data = np.asarray(X_data, dtype=np.float32)
atom_mask = np.asarray(mask_data, dtype=np.float32)
y_data = np.asarray(y_data, dtype=np.float32)

print(X_data.shape, atom_mask.shape, y_data.shape)
# Out:
# (131929, 29, 80) (131929, 29) (131929,)

# %%
def atomic_network(n_features):
  reg = tf.keras.regularizers.l2(1e-6)
  inputs = tf.keras.layers.Input(shape=(n_features,))
  x = tf.keras.layers.Dense(160, activation="relu", kernel_regularizer=reg)(inputs)
  x = tf.keras.layers.Dense(128, activation="relu", kernel_regularizer=reg)(x)
  x = tf.keras.layers.Dense(96, activation="relu", kernel_regularizer=reg)(x)
  outputs = tf.keras.layers.Dense(1)(x)
  return tf.keras.Model(inputs, outputs)

# %%
n_features = X_data.shape[2]
atomic_model = atomic_network(n_features)
feat_in = tf.keras.layers.Input(shape=(max_atoms, n_features), name="features")
mask_in = tf.keras.layers.Input(shape=(max_atoms,), name="mask")
atomic_energies = tf.keras.layers.TimeDistributed(atomic_model)(feat_in)

def masked_atomic_sum(args):
  ae, mask = args
  return tf.reduce_sum(ae * tf.expand_dims(mask, -1), axis=1)

total_energy = tf.keras.layers.Lambda(masked_atomic_sum)([atomic_energies, mask_in])
model = tf.keras.Model(inputs=[feat_in, mask_in], outputs=total_energy)
model.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  features (InputLayer)       [(None, 29, 80)]             0         []
#
#  time_distributed (TimeDist  (None, 29, 1)                46049     ['features[0][0]']
#  ributed)
#
#  mask (InputLayer)           [(None, 29)]                 0         []
#
#  lambda (Lambda)             (None, 1)                    0         ['time_distributed[0][0]',
#                                                                      'mask[0][0]']
#
# ==================================================================================================
# Total params: 46049 (179.88 KB)
# Trainable params: 46049 (179.88 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________
# 2026-05-10 13:55:46.847635: E external/local_xla/xla/stream_executor/cuda/cuda_driver.cc:274] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-3),
    loss="mse",
    metrics=["mae"],
)

# %%
X_train, X_test, m_train, m_test, y_train, y_test = train_test_split(
    X_data, atom_mask, y_data, test_size=0.2, random_state=42
)

# %%
callbacks = [
    tf.keras.callbacks.EarlyStopping(
        monitor="val_mae", patience=10, restore_best_weights=True, min_delta=1e-4
    ),
    tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", factor=0.5, patience=4, min_lr=1e-5
    ),
]
model.fit(
    [X_train, m_train],
    y_train,
    validation_split=0.2,
    epochs=80,
    batch_size=64,
    callbacks=callbacks,
    verbose=1,
)
# Out:
# Epoch 1/80
# 1320/1320 [==============================] - 5s 4ms/step - loss: 2670.3003 - mae: 21.3606 - val_loss: 140.3603 - val_mae: 9.5723 - lr: 0.0010
# Epoch 2/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 71.8817 - mae: 6.5906 - val_loss: 34.3256 - val_mae: 4.5712 - lr: 0.0010
# Epoch 3/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 34.3751 - mae: 4.6091 - val_loss: 22.8783 - val_mae: 3.7468 - lr: 0.0010
# Epoch 4/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 25.7792 - mae: 3.9990 - val_loss: 37.1795 - val_mae: 5.0018 - lr: 0.0010
# Epoch 5/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 21.7953 - mae: 3.6738 - val_loss: 15.5181 - val_mae: 3.0408 - lr: 0.0010
# Epoch 6/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 18.9162 - mae: 3.4172 - val_loss: 14.9340 - val_mae: 3.0030 - lr: 0.0010
# Epoch 7/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 15.9617 - mae: 3.1357 - val_loss: 24.4814 - val_mae: 4.1655 - lr: 0.0010
# Epoch 8/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 14.8233 - mae: 3.0154 - val_loss: 10.1970 - val_mae: 2.4536 - lr: 0.0010
# Epoch 9/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 12.6623 - mae: 2.7872 - val_loss: 8.5137 - val_mae: 2.2603 - lr: 0.0010
# Epoch 10/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 11.3222 - mae: 2.6399 - val_loss: 7.2650 - val_mae: 2.0828 - lr: 0.0010
# Epoch 11/80
# 1320/1320 [==============================] - 5s 3ms/step - loss: 10.4834 - mae: 2.5406 - val_loss: 12.4401 - val_mae: 2.8843 - lr: 0.0010
# Epoch 12/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 9.2433 - mae: 2.3847 - val_loss: 6.2484 - val_mae: 1.9663 - lr: 0.0010
# Epoch 13/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 8.7374 - mae: 2.3137 - val_loss: 23.1134 - val_mae: 4.3084 - lr: 0.0010
# Epoch 14/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 8.5299 - mae: 2.2882 - val_loss: 10.4918 - val_mae: 2.7182 - lr: 0.0010
# Epoch 15/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 7.1270 - mae: 2.0886 - val_loss: 5.4237 - val_mae: 1.8301 - lr: 0.0010
# Epoch 16/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 6.8478 - mae: 2.0485 - val_loss: 9.7443 - val_mae: 2.6069 - lr: 0.0010
# Epoch 17/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 6.6570 - mae: 2.0190 - val_loss: 4.3248 - val_mae: 1.6383 - lr: 0.0010
# Epoch 18/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 5.9128 - mae: 1.9028 - val_loss: 3.7660 - val_mae: 1.4875 - lr: 0.0010
# Epoch 19/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 5.8274 - mae: 1.8920 - val_loss: 3.0513 - val_mae: 1.3340 - lr: 0.0010
# Epoch 20/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 5.6177 - mae: 1.8514 - val_loss: 6.7086 - val_mae: 2.1376 - lr: 0.0010
# Epoch 21/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 4.9587 - mae: 1.7461 - val_loss: 10.3131 - val_mae: 2.8380 - lr: 0.0010
# Epoch 22/80
# 1320/1320 [==============================] - 5s 4ms/step - loss: 4.9963 - mae: 1.7389 - val_loss: 4.2301 - val_mae: 1.6555 - lr: 0.0010
# Epoch 23/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 4.7680 - mae: 1.7131 - val_loss: 7.0347 - val_mae: 2.2799 - lr: 0.0010
# Epoch 24/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.5665 - mae: 1.2327 - val_loss: 6.0749 - val_mae: 2.1124 - lr: 5.0000e-04
# Epoch 25/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.7018 - mae: 1.2731 - val_loss: 4.6611 - val_mae: 1.7959 - lr: 5.0000e-04
# Epoch 26/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.4976 - mae: 1.2251 - val_loss: 2.7309 - val_mae: 1.3125 - lr: 5.0000e-04
# Epoch 27/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.5565 - mae: 1.2390 - val_loss: 5.5227 - val_mae: 2.0432 - lr: 5.0000e-04
# Epoch 28/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.3327 - mae: 1.1790 - val_loss: 1.5739 - val_mae: 0.9460 - lr: 5.0000e-04
# Epoch 29/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.3666 - mae: 1.1915 - val_loss: 1.8975 - val_mae: 1.0672 - lr: 5.0000e-04
# Epoch 30/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.2207 - mae: 1.1516 - val_loss: 1.8133 - val_mae: 1.0641 - lr: 5.0000e-04
# Epoch 31/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 2.1980 - mae: 1.1443 - val_loss: 7.7893 - val_mae: 2.5624 - lr: 5.0000e-04
# Epoch 32/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.9751 - mae: 1.0856 - val_loss: 4.7736 - val_mae: 1.9221 - lr: 5.0000e-04
# Epoch 33/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.3891 - mae: 0.8989 - val_loss: 1.9105 - val_mae: 1.1229 - lr: 2.5000e-04
# Epoch 34/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.4317 - mae: 0.9182 - val_loss: 2.3804 - val_mae: 1.2724 - lr: 2.5000e-04
# Epoch 35/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.3769 - mae: 0.8978 - val_loss: 1.0772 - val_mae: 0.7746 - lr: 2.5000e-04
# Epoch 36/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.3488 - mae: 0.8908 - val_loss: 1.4889 - val_mae: 0.9588 - lr: 2.5000e-04
# Epoch 37/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.3420 - mae: 0.8882 - val_loss: 1.2156 - val_mae: 0.8366 - lr: 2.5000e-04
# Epoch 38/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.2799 - mae: 0.8684 - val_loss: 1.1422 - val_mae: 0.7991 - lr: 2.5000e-04
# Epoch 39/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.2713 - mae: 0.8636 - val_loss: 1.0093 - val_mae: 0.7546 - lr: 2.5000e-04
# Epoch 40/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.1879 - mae: 0.8354 - val_loss: 1.6064 - val_mae: 1.0297 - lr: 2.5000e-04
# Epoch 41/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.2189 - mae: 0.8447 - val_loss: 2.4524 - val_mae: 1.3365 - lr: 2.5000e-04
# Epoch 42/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.1490 - mae: 0.8186 - val_loss: 2.4342 - val_mae: 1.3410 - lr: 2.5000e-04
# Epoch 43/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 1.1513 - mae: 0.8217 - val_loss: 1.1208 - val_mae: 0.8155 - lr: 2.5000e-04
# Epoch 44/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8925 - mae: 0.7137 - val_loss: 1.0822 - val_mae: 0.7999 - lr: 1.2500e-04
# Epoch 45/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8870 - mae: 0.7114 - val_loss: 0.8167 - val_mae: 0.6707 - lr: 1.2500e-04
# Epoch 46/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8768 - mae: 0.7072 - val_loss: 0.8892 - val_mae: 0.7162 - lr: 1.2500e-04
# Epoch 47/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8776 - mae: 0.7078 - val_loss: 0.7542 - val_mae: 0.6451 - lr: 1.2500e-04
# Epoch 48/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8759 - mae: 0.7082 - val_loss: 0.7325 - val_mae: 0.6311 - lr: 1.2500e-04
# Epoch 49/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8416 - mae: 0.6939 - val_loss: 0.9907 - val_mae: 0.7705 - lr: 1.2500e-04
# Epoch 50/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8318 - mae: 0.6890 - val_loss: 0.9592 - val_mae: 0.7565 - lr: 1.2500e-04
# Epoch 51/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.8212 - mae: 0.6850 - val_loss: 0.7237 - val_mae: 0.6346 - lr: 1.2500e-04
# Epoch 52/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.7988 - mae: 0.6743 - val_loss: 0.6795 - val_mae: 0.6083 - lr: 1.2500e-04
# Epoch 53/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.7738 - mae: 0.6619 - val_loss: 0.6941 - val_mae: 0.6130 - lr: 1.2500e-04
# Epoch 54/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.7943 - mae: 0.6750 - val_loss: 0.7012 - val_mae: 0.6236 - lr: 1.2500e-04
# Epoch 55/80
# 1320/1320 [==============================] - 5s 3ms/step - loss: 0.7666 - mae: 0.6602 - val_loss: 1.6407 - val_mae: 1.0865 - lr: 1.2500e-04
# Epoch 56/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.7581 - mae: 0.6577 - val_loss: 0.8286 - val_mae: 0.6975 - lr: 1.2500e-04
# Epoch 57/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6559 - mae: 0.6048 - val_loss: 0.7158 - val_mae: 0.6331 - lr: 6.2500e-05
# Epoch 58/80
# 1320/1320 [==============================] - 5s 4ms/step - loss: 0.6607 - mae: 0.6073 - val_loss: 0.6539 - val_mae: 0.5973 - lr: 6.2500e-05
# Epoch 59/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6578 - mae: 0.6077 - val_loss: 0.6655 - val_mae: 0.6038 - lr: 6.2500e-05
# Epoch 60/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6377 - mae: 0.5964 - val_loss: 0.6070 - val_mae: 0.5720 - lr: 6.2500e-05
# Epoch 61/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6488 - mae: 0.6034 - val_loss: 0.6034 - val_mae: 0.5682 - lr: 6.2500e-05
# Epoch 62/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6356 - mae: 0.5960 - val_loss: 0.6778 - val_mae: 0.6109 - lr: 6.2500e-05
# Epoch 63/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6321 - mae: 0.5943 - val_loss: 0.7471 - val_mae: 0.6461 - lr: 6.2500e-05
# Epoch 64/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6216 - mae: 0.5888 - val_loss: 0.5745 - val_mae: 0.5541 - lr: 6.2500e-05
# Epoch 65/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6197 - mae: 0.5875 - val_loss: 0.8419 - val_mae: 0.7156 - lr: 6.2500e-05
# Epoch 66/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6163 - mae: 0.5856 - val_loss: 0.6683 - val_mae: 0.6134 - lr: 6.2500e-05
# Epoch 67/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.6019 - mae: 0.5785 - val_loss: 0.5964 - val_mae: 0.5671 - lr: 6.2500e-05
# Epoch 68/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.5916 - mae: 0.5721 - val_loss: 1.2437 - val_mae: 0.8984 - lr: 6.2500e-05
# Epoch 69/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.5565 - mae: 0.5523 - val_loss: 0.5660 - val_mae: 0.5522 - lr: 3.1250e-05
# Epoch 70/80
# 1320/1320 [==============================] - 5s 4ms/step - loss: 0.5541 - mae: 0.5519 - val_loss: 0.5658 - val_mae: 0.5534 - lr: 3.1250e-05
# Epoch 71/80
# 1320/1320 [==============================] - 6s 5ms/step - loss: 0.5505 - mae: 0.5495 - val_loss: 0.5646 - val_mae: 0.5482 - lr: 3.1250e-05
# Epoch 72/80
# 1320/1320 [==============================] - 6s 4ms/step - loss: 0.5456 - mae: 0.5464 - val_loss: 0.6355 - val_mae: 0.5962 - lr: 3.1250e-05
# Epoch 73/80
# 1320/1320 [==============================] - 6s 4ms/step - loss: 0.5512 - mae: 0.5506 - val_loss: 0.5385 - val_mae: 0.5352 - lr: 3.1250e-05
# Epoch 74/80
# 1320/1320 [==============================] - 6s 5ms/step - loss: 0.5397 - mae: 0.5435 - val_loss: 0.6915 - val_mae: 0.6382 - lr: 3.1250e-05
# Epoch 75/80
# 1320/1320 [==============================] - 6s 5ms/step - loss: 0.5437 - mae: 0.5465 - val_loss: 0.5515 - val_mae: 0.5439 - lr: 3.1250e-05
# Epoch 76/80
# 1320/1320 [==============================] - 7s 5ms/step - loss: 0.5346 - mae: 0.5415 - val_loss: 0.6120 - val_mae: 0.5804 - lr: 3.1250e-05
# Epoch 77/80
# 1320/1320 [==============================] - 7s 5ms/step - loss: 0.5300 - mae: 0.5381 - val_loss: 0.6243 - val_mae: 0.5941 - lr: 3.1250e-05
# Epoch 78/80
# 1320/1320 [==============================] - 5s 4ms/step - loss: 0.5053 - mae: 0.5233 - val_loss: 0.5375 - val_mae: 0.5366 - lr: 1.5625e-05
# Epoch 79/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.5054 - mae: 0.5239 - val_loss: 0.5359 - val_mae: 0.5341 - lr: 1.5625e-05
# Epoch 80/80
# 1320/1320 [==============================] - 4s 3ms/step - loss: 0.5081 - mae: 0.5253 - val_loss: 0.5343 - val_mae: 0.5351 - lr: 1.5625e-05

# %%
model.evaluate([X_test, m_test], y_test, verbose=1)
# Out:
# 825/825 [==============================] - 1s 1ms/step - loss: 0.5507 - mae: 0.5342
# [0.5507476329803467, 0.5341519117355347]

# %%
y_pred = model.predict([X_test, m_test], verbose=1)
# Out:
# 825/825 [==============================] - 1s 1ms/step

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

y_p = np.asarray(y_pred).reshape(-1)
print(f"Test MAE:  {mean_absolute_error(y_test, y_p):.6f}")
print(f"Test RMSE: {np.sqrt(mean_squared_error(y_test, y_p)):.6f}")
print(f"Test R²:   {r2_score(y_test, y_p):.6f}")
# Out:
# Test MAE:  0.534152
# Test RMSE: 0.738353
# Test R²:   0.999664

# %%
print(
    "Test MAE (numpy):",
    float(np.mean(np.abs(y_test - np.asarray(y_pred).reshape(-1)))),
)
# Out:
# Test MAE (numpy): 0.5341519713401794

# %%
import matplotlib.pyplot as plt

y_t = np.asarray(y_test).ravel()
y_p = np.asarray(y_pred).ravel()
lim = [min(y_t.min(), y_p.min()), max(y_t.max(), y_p.max())]

fig, axes = plt.subplots(1, 2, figsize=(11, 4.5))
ax = axes[0]
ax.scatter(y_t, y_p, alpha=0.15, s=8, c="C0", rasterized=True)
ax.plot(lim, lim, "k--", lw=1, label="ideal")
ax.set_xlabel("True (target)")
ax.set_ylabel("Predicted")
ax.set_title("Parity")
ax.legend()
ax.set_aspect("equal", adjustable="box")

ax2 = axes[1]
res = y_p - y_t
ax2.scatter(y_t, res, alpha=0.15, s=8, c="C3", rasterized=True)
ax2.axhline(0.0, color="k", linestyle="--", lw=1)
ax2.set_xlabel("True (target)")
ax2.set_ylabel("Residual (pred − true)")
ax2.set_title("Residuals")

plt.tight_layout()
plt.show()

# %%
idx = 10
X_single = X_data[idx : idx + 1]
mask_single = atom_mask[idx : idx + 1]
prediction = model.predict([X_single, mask_single], verbose=0)
print("Predicted: ", prediction[0][0])
print("True: ", y_data[idx])
# Out:
# Predicted:  -156.31792
# True:  -153.78279
